# %% [markdown]
# #### 문제
# - selenium의 webdriver을 이용하여 `https://comp.wisereport.co.kr/company/c1010001.aspx` 주소로 접속
# - 해당 페이지의 html 문서를 불러와서 BeautifulSoup 타입으로 파싱
# - div 태그중 class의 값이 'fl_le' 태그들을 모두 찾는다.
# - 태그들 중 table을 정보가 주요 지표, 어닝서프라이즈 태그들을 추출하여 문자로 변경
# - pandas 에 read_html()을 이용하여 데이터프레임으로 변환
# - 해당 데이터프레임들을 DB server에 table1, table2라는 이름으로 저장 (to_sql() 사용)

# %%
import pandas as pd 
from bs4 import BeautifulSoup as bs
from selenium import webdriver
from sqlalchemy import create_engine

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://comp.wisereport.co.kr/company/c1010001.aspx')

# %%
# driver의 페이지소스를 python으로 로드 
html_data = driver.page_source

# %%
soup = bs(html_data, 'html.parser')

# %%
# div 태그중 class 가 fl_le인 태그를 모두 찾는다. 
div_list = soup.find_all(
    'div', 
    attrs = {
        'class' : 'fl_le'
    }
)
len(div_list)
# Out:
# 5

# %%
# 이 영역중에 주요지표 테이블 영역이랑 어닝서프라이즈 테이블 영역만 확인 
div_list[4]
# Out:
# <div class="half fl_le">
# <h6 class="spanCT" tabindex="0">PER 차트</h6>
# <a class="viewCT" href="javascript:;" title="레이어로 자료보기"><span class="icon-sprite icon-data" id="ct4">자료보기</span></a>
# <div class="gHead" id="gHeadCt4">
# <div class="pop-info" id="frmCt4" name="frmCt4"></div>
# <a class="blind" href="#sct5"><strong>차트 건너뛰기</strong>"데이터를 차트로 제공하고 있습니다. 차트를 건너뛰고 싶은 경우 이 링크를 선택하시기 바랍니다."</a>
# <div class="chart-container" data-highcharts-chart="2" id="per-chart" style="height: 225px"><div class="highcharts-container" id="highcharts-4" style='position: relative; overflow: hidden; width: 438px; height: 225px; text-align: left; line-height: normal; z-index: 0; -webkit-tap-highlight-color: rgba(0, 0, 0, 0); font-family: "맑은 고딕", Tahoma, "Lucida Grande", "Lucida Sans Unicode", Verdana, Arial, Helvetica, sans-serif; font-size: 10px; touch-action: none;'><svg height="225" version="1.1" width="438" xmlns="http://www.w3.org/2000/svg"><desc>Created with Highcharts 3.0.9</desc><defs><clippath id="highcharts-5"><rect fill="none" height="160" width="368" x="0" y="0"></rect></clippath></defs><rect fill="#FFFFFF" height="225" rx="5" ry="5" width="438" x="0" y="0"></rect><g class="highcharts-grid" zindex="1"></g><g class="highcharts-grid" zindex="1"><path d="M 60 24.5 L 428 24.5" fill="none" opacity="1" stroke="#dfdfdf" stroke-dasharray="none" stroke-width="1" zindex="1"></path><path d="M 60 65.5 L 428 65.5" fill="none" opacity="1" stroke="#dfdfdf" stroke-dasharray="none" stroke-width="1" zindex="1"></path><path d="M 60 105.5 L 428 105.5" fill="none" opacity="1" stroke="#dfdfdf" stroke-dasharray="none" stroke-width="1" zindex="1"></path><path d="M 60 145.5 L 428 145.5" fill="none" opacity="1" stroke="#dfdfdf" stroke-dasharray="none" stroke-width="1" zindex="1"></path><path d="M 60 185.5 L 428 185.5" fill="none" opacity="1" stroke="#dfdfdf" stroke-dasharray="none" stroke-width="1" zindex="1"></path></g><g class="highcharts-axis" zindex="2"><path d="M 165.5 185 L 165.5 190" fill="none" opacity="1" stroke="#C0D0E0" stroke-width="1"></path><path d="M 287.5 185 L 287.5 190" fill="none" opacity="1" stroke="#C0D0E0" stroke-width="1"></path><path d="M 408.5 185 L 408.5 190" fill="none" opacity="1" stroke="#C0D0E0" stroke-width="1"></path><path d="M 60 185.5 L 428 185.5" fill="none" stroke="#C0D0E0" stroke-width="1" visibility="visible" zindex="7"></path></g><g class="highcharts-axis" zindex="2"></g><g class="highcharts-series-group" zindex="3"><g class="highcharts-series" clip-path="url(#highcharts-5)" transform="translate(60,25) scale(1 1)" visibility="visible" zindex="0.1"><path d="M 3.6078431372549016 157.489792 L 8.945382683817863 157.416832 L 13.94932600872064 157.343872 L 18.786471222793324 157.270912 L 24.290808880186376 157.197952 L 29.294752205089154 157.124992 L 34.46549364082202 157.052032 L 39.469436965724796 156.979072 L 44.30658217979748 156.906112 L 49.81091983719053 157.095808 L 54.48126694043312 157.285504 L 59.652008376165995 157.474816 L 64.32235547940859 157.664512 L 69.82669313680164 157.854208 L 74.83063646170442 158.043904 L 80.00137789743728 158.2336 L 85.17211933317016 158.423296 L 89.67566832558265 158.612992 L 95.3468040938058 158.802688 L 100.35074741870858 158.992 L 105.02109452195117 159.181696 L 110.69223029017431 159.091456 L 115.529375504247 159.001216 L 120.36652071831968 158.91136 L 125.70406026488264 158.82112 L 130.8748017006155 158.73088 L 135.5451488038581 158.64064 L 141.04948646125115 158.5504 L 146.05342978615394 158.46016 L 151.2241712218868 158.36992 L 156.39491265761967 158.27968 L 161.23205787169235 158.18944 L 166.40279930742523 158.0992 L 171.7403388539882 158.047744 L 176.41068595723078 157.995904 L 181.58142739296363 157.944448 L 186.58537071786643 157.892608 L 191.5893140427692 157.841152 L 196.76005547850207 157.789312 L 201.93079691423492 157.737856 L 206.76794212830762 157.686016 L 212.10548167487056 157.63456 L 217.27622311060344 157.58272 L 221.94657021384603 157.531264 L 227.284109760409 157.479424 L 232.45485119614187 156.513664 L 237.12519829938446 155.547904 L 242.4627378459474 154.582144 L 247.4666811708502 153.616384 L 252.63742260658307 152.650624 L 257.64136593148584 151.684864 L 262.8121073672187 150.719104 L 267.9828488029516 149.753344 L 272.98679212785436 148.78719999999998 L 278.1575335635872 147.82144 L 283.16147688849 146.85568 L 288.3322183242229 145.88992 L 293.502959 ...
# </div>
# </div>

# %%
# Tag 안에 찾는 단어가 존재 하는가?
# Tag 데이터에서 모든 콘첸츠 데이터를 추출 -> get_text()
# 우리가 원하는 단어가 존재하는가? -> find(), in 연산자 
list(
    map(
        lambda x :  '주요지표' in x.get_text() or '어닝서프라이즈' in x.get_text(), # x에는 Tag 데이터 대입
        div_list
    )
)
# Out:
# [False, True, True, False, False]

# %%
str(div_list[1])
# Out:
# '<div class="fl_le" style="width: 45%">\n<table class="gHead03" style="width: 95%" summary="기업 펀더멘털 실적, 컨센서스 정보 리스트입니다.P/E(지배), P/B(지배), EV/EBITDA. EV/Sales, EPS(지배), BPS(지배), EBITDA, EBIT, 수정DPS, 배당수익률에 대해서 보여주는 리스트입니다.">\n<caption class="blind">기업 펀더멘털 실적, 컨센서스</caption>\n<colgroup>\n<col width="28%"/>\n<col width="24%"/>\n<col width="24%"/>\n<col width="24%"/>\n</colgroup>\n<thead>\n<tr>\n<th style="padding: 0">주요지표</th>\n<th style="padding: 0">2025/12(A)</th>\n<th style="padding: 0">2026/12(E)</th>\n<th class="no-line" style="padding: 0">Fwd. 12M(E)</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<th class="left" scope="row">PER</th>\n<td class="num">33.14</td>\n<td class="num line">5.92</td>\n<td class="num line">5.52</td>\n</tr>\n<tr>\n<th class="left" scope="row">PBR</th>\n<td class="num">3.40</td>\n<td class="num line">2.19</td>\n<td class="num line">1.92</td>\n</tr>\n<tr>\n<th class="left" scope="row">PCR</th>\n<td class="num">17.19</td>\n<td class="num line">4.94</td>\n<td class="num line">4.65</td>\n</tr>\n<tr>\n<th class="left" scope="row">EV/EBITDA</th>\n<td class="num">14.28</td>\n<td class="num line">3.19</td>\n<td class="num line">2.78</td>\n</tr>\n<tr>\n<th class="left" scope="row">EPS</th>\n<td class="num">6,564원</td>\n<td class="num line">36,745원</td>\n<td class="num line">39,438원</td>\n</tr>\n<tr>\n<th class="left" scope="row">BPS</th>\n<td class="num">63,997원</td>\n<td class="num line">99,252원</td>\n<td class="num line">113,104원</td>\n</tr>\n<tr>\n<th class="left" scope="row">EBITDA</th>\n<td class="num">905,276.4억원</td>\n<td class="num line">3,534,695.2억원</td>\n<td class="num line">3,768,787.8억원</td>\n</tr>\n<tr>\n<th class="left" scope="row">현금DPS</th>\n<td class="num">1,668원</td>\n<td class="num line">3,292원</td>\n<td class="num line">2,999원</td>\n</tr>\n<tr>\n<th class="left" scope="row">현금배당수익률</th>\n<td class="num">0.77%</td>\n<td class="num line">1.51%</td>\n<td class="num line">1.38%</td>\n</tr>\n<tr>\n<th class="left" scope="row">회계기준</th>\n<td class="num">연결</td>\n<td class="num line">연결</td>\n<td class="num line">연결</td>\n</tr>\n</tbody>\n</table>\n<dl class="annotation mb-16 per95">\n<dd class="section01 cursor">\n<ul>\n<li>* Fwd. 12M : 익월부터 향후 12개월의 컨센서스 </li>\n</ul>\n</dd>\n<dd class="section02">\n<ul>\n<li>* (A)는 실적, (E)는 컨센서스</li>\n<li>* 컨센서스 : 최근 3개월간 증권사에서 발표한 추정치의 평균</li>\n<li>* 지표 계산 시 주가 : 전 영업일 보통주 수정주가</li>\n<li>* 연결 기업의 당기순이익 및 자본총계는 지배주주 기준</li>\n</ul>\n</dd>\n<dd class="section03"><a class="off text-hide" href="javascript:;" title="주석 펼치기/접기">주석 펼치기/접기</a></dd>\n</dl>\n</div>'

# %%
from io import StringIO

# %%
# read_html() 함수를 이용해서 데이터프레임화 
# read_html() 함수의 결과 -> list -> [df, df, df]
# 첫번째 인자 :  Tag로 이루어진 문자열
pd.read_html( StringIO(str(div_list[2])) )
# Out:
# [   어닝서프라이즈 * 단위: 억원, % 어닝서프라이즈 * 단위: 억원, %.1 어닝서프라이즈 * 단위: 억원, %.2  \
#  0                 재무연월                  재무연월               2025/09
#  1                 영업이익                  컨센서스              101922.8
#  2                 영업이익                   잠정치              121000.0
#  3                 영업이익              Surprise                 18.72
#  4                 영업이익         전분기대비보기전년동기대비                 31.76
#  5                  NaN                 전분기대비                158.77
#  6                  NaN                   NaN                   NaN
#  7                당기순이익                  컨센서스               96001.6
#  8                당기순이익                   잠정치           ● 120,064.0
#  9                당기순이익              Surprise                 25.06
#  10               당기순이익         전분기대비보기전년동기대비                 22.75
#  11                 NaN                 전분기대비                143.34
#  12     잠정치발표(예정)일/회계기준       잠정치발표(예정)일/회계기준        2025/10/14(연결)
#
#     어닝서프라이즈 * 단위: 억원, %.3 어닝서프라이즈 * 단위: 억원, %.4
#  0                2025/12               2026/03
#  1               185098.0              401923.4
#  2               200000.0              572000.0
#  3                   8.05                 42.32
#  4                 208.04                755.61
#  5                  64.39                184.95
#  6                    NaN                   NaN
#  7               163415.8              314258.0
#  8            ● 192,920.0                   NaN
#  9                  18.05                   NaN
#  10                154.64                   NaN
#  11                 60.68                   NaN
#  12        2026/01/08(연결)        2026/04/07(연결)  ]

# %%
df1 = pd.read_html(StringIO(str(div_list[1])))[0]
df1
# Out:
#         주요지표   2025/12(A)     2026/12(E)    Fwd. 12M(E)
# 0        PER        33.14           5.92           5.52
# 1        PBR         3.40           2.19           1.92
# 2        PCR        17.19           4.94           4.65
# 3  EV/EBITDA        14.28           3.19           2.78
# 4        EPS       6,564원        36,745원        39,438원
# 5        BPS      63,997원        99,252원       113,104원
# 6     EBITDA  905,276.4억원  3,534,695.2억원  3,768,787.8억원
# 7      현금DPS       1,668원         3,292원         2,999원
# 8    현금배당수익률        0.77%          1.51%          1.38%
# 9       회계기준           연결             연결             연결

# %%
df2 = pd.read_html(StringIO(str(div_list[2])))[0]
df2
# Out:
#    어닝서프라이즈 * 단위: 억원, % 어닝서프라이즈 * 단위: 억원, %.1 어닝서프라이즈 * 단위: 억원, %.2  \
# 0                 재무연월                  재무연월               2025/09
# 1                 영업이익                  컨센서스              101922.8
# 2                 영업이익                   잠정치              121000.0
# 3                 영업이익              Surprise                 18.72
# 4                 영업이익         전분기대비보기전년동기대비                 31.76
# 5                  NaN                 전분기대비                158.77
# 6                  NaN                   NaN                   NaN
# 7                당기순이익                  컨센서스               96001.6
# 8                당기순이익                   잠정치           ● 120,064.0
# 9                당기순이익              Surprise                 25.06
# 10               당기순이익         전분기대비보기전년동기대비                 22.75
# 11                 NaN                 전분기대비                143.34
# 12     잠정치발표(예정)일/회계기준       잠정치발표(예정)일/회계기준        2025/10/14(연결)
#
#    어닝서프라이즈 * 단위: 억원, %.3 어닝서프라이즈 * 단위: 억원, %.4
# 0                2025/12               2026/03
# 1               185098.0              401923.4
# 2               200000.0              572000.0
# 3                   8.05                 42.32
# 4                 208.04                755.61
# 5                  64.39                184.95
# 6                    NaN                   NaN
# 7               163415.8              314258.0
# 8            ● 192,920.0                   NaN
# 9                  18.05                   NaN
# 10                154.64                   NaN
# 11                 60.68                   NaN
# 12        2026/01/08(연결)        2026/04/07(연결)

# %%
df2.drop(index=6, inplace=True)

# %%
df2.iloc[:, 0] = df2.iloc[:, 0].ffill()

# %%
df2
# Out:
#    어닝서프라이즈 * 단위: 억원, % 어닝서프라이즈 * 단위: 억원, %.1 어닝서프라이즈 * 단위: 억원, %.2  \
# 0                 재무연월                  재무연월               2025/09
# 1                 영업이익                  컨센서스              101922.8
# 2                 영업이익                   잠정치              121000.0
# 3                 영업이익              Surprise                 18.72
# 4                 영업이익         전분기대비보기전년동기대비                 31.76
# 5                 영업이익                 전분기대비                158.77
# 7                당기순이익                  컨센서스               96001.6
# 8                당기순이익                   잠정치           ● 120,064.0
# 9                당기순이익              Surprise                 25.06
# 10               당기순이익         전분기대비보기전년동기대비                 22.75
# 11               당기순이익                 전분기대비                143.34
# 12     잠정치발표(예정)일/회계기준       잠정치발표(예정)일/회계기준        2025/10/14(연결)
#
#    어닝서프라이즈 * 단위: 억원, %.3 어닝서프라이즈 * 단위: 억원, %.4
# 0                2025/12               2026/03
# 1               185098.0              401923.4
# 2               200000.0              572000.0
# 3                   8.05                 42.32
# 4                 208.04                755.61
# 5                  64.39                184.95
# 7               163415.8              314258.0
# 8            ● 192,920.0                   NaN
# 9                  18.05                   NaN
# 10                154.64                   NaN
# 11                 60.68                   NaN
# 12        2026/01/08(연결)        2026/04/07(연결)

# %%
from urllib.parse import quote_plus

pw = quote_plus('shinjaeho615@')

engine = create_engine(
    "mysql+pymysql://root:{pw}@localhost:3306/multicam"
)

# %%
df1.to_sql(
    name = 'table1', 
    con = engine
)

# %%
df2.to_sql(
    name = 'table2', 
    con = engine
)
# Out:
# 12
