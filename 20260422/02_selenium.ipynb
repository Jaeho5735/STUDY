# %%
import requests 
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
# 네이버 쇼핑 주소를 이용하여 requests.get() html 문서를 받아온다. 
res = requests.get('http://search.shopping.naver.com/search/all?where=all&frm=NVSCTAB&query=%EC%95%84%EC%9D%B4%ED%8F%B0')

# bs 타입 변경 
soup = bs(res.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <style>
#     * {
#       margin: 0;
#       padding: 0;
#     }
#     html, body {
#       height: 100%;
#     }
#     body {
#       display: flex;
#       align-items: center;
#       justify-content: center;
#       background: #fff;
#       font-family: -apple-system, BlinkMacSystemFont, HelveticaNeue,
#       AppleSDGothicNeo, sans-serif;
#     }
#     a {
#       text-decoration: none;
#       color: #00c73c;
#     }
#     .content_error {
#       line-height: 19px;
#       max-width: 578px;
#       padding: 64px 40px;
#       letter-spacing: -0.5px;
#       text-align: center;
#       word-break: keep-all;
#     }
#     .content_error:before {
#       display: block;
#       width: 64px;
#       height: 64px;
#       margin: 0 auto;
#       background: url(https://ssl.pstatic.net/shoppingsearch/static/icons/img_error.png) no-repeat 0 0;
#       -webkit-background-size: 64px;
#       background-size: 64px;
#       content: '';
#     }
#     .content_error .head {
#       line-height: 28px;
#       margin-top: 12px;
#       font-size: 20px;
#       color: #121212;
#       font-weight: bold;
#     }
#     .content_error .desc {
#       margin-top: 8px;
#       font-size: 14px;
#       color: #3f3f3f;
#     }
#     .content_error .reason {
#       background-color: #f8f9fd;
#       margin-top: 14px;
#       padding: 14px 0;
#       border-radius: 6px;
#       font-size: 14px;
#       color: #7a7a7a;
#       list-style: none;
#     }
#     .content_error .reason li:before {
#       display: inline-block;
#       width: 3px;
#       height: 3px;
#       margin: 9px 5px 0 0;
#       border-radius: 50%;
#       background-color: #babbbe;
#       vertical-align: top;
#       content: '';
#     }
#     .content_error .footer {
#       margin-top: 14px;
#       font-size: 14px;
#       color: #949494;
#     }
#   </style>
# <title>네이버쇼핑</title>
# </head>
# <body>
# <div class="content_error">
# <div class="head">쇼핑 서비스 접속이 일시적으로 제한되었습니다. </div>
# <div class="desc">
#     네이버는 안정적인 쇼핑 서비스 제공하고자 시스템을 통해 아래와 같은 비정상적인 접근이 감지될 경우 해당 네트워크의 접속을 일시적으로 제한하고 있습니다.
#   </div>
# <ul class="reason">
# <li>상품 구매, 탐색과 무관한 외부 이벤트를 통한 접속</li>
# <li>짧은 시간 내에 너무 많은 요청이 이루어진 IP</li>
# <li>VPN을 사용하여 접속한 IP</li>
# <li>특정 확장 프로그램 이용 시</li>
# </ul>
# <div class="footer">위와 같은 접근이 아님에도 접속이 제한된 경우,네이버앱을 업데이트 또는 <a href="https://help.naver.com/service/30016/category/5278" target="_blank">원클릭 진단</a>을 부탁드립니다.<br/> 해당 방법을 통해서도 접속이 불가한 경우 <a href="https://help.pay.naver.com/mail/form.help?alias=shopping_stop" target="_blank">네이버쇼핑 고객센터</a>로 문의 부탁드립니다.</div>
# </div>
# </body>
# </html>

# %%
# webdriver -> 웹 브라우져을 제어
from selenium import webdriver
# By -> element(Tag) 접근하기 위한 기능
from selenium.webdriver.common.by import By
# Keys -> 키보드의 이벤트들
from selenium.webdriver.common.keys import Keys

# %%
# 웹 브라우져를 실행 -> 웹브라우져를 제어(변수에 저장)
driver = webdriver.Chrome()

# %%
# 웹 브라우져에 주소를 입력 
driver.get('http://www.naver.com')

# %% [markdown]
# #### seleniumd안에 webdriver에서 Tag를 찾는 내장 함수
# - find_element()
#     - 특정 조건에 맞은 태그 중 첫번째 태그를 선택
#     - bs에서 find() 흡사한 기능
# - find_elements()
#     - 특정 조건에 맞는 태그 모두를 추출
#     - bs에서 find_all() 흡사한 기능
#     - tag들이 모인 list형태라 생각하시면 됨

# %%
# 네이버 메인 화면에서 검색어를 입력하는 input Tag는 id 가 query 이다. 
search_element = driver.find_element(By.ID, 'query')

# %%
# search_element -> 검색어 입력창
# 입력할 데이터를 보내준다. python에서 webdriver로 보낸다. 
search_element.send_keys('아이폰')

# %%
# 검색어의 입력이 끝났으면 ENTER키를 눌러서 검색을 시작 
# 키보드 이벤트 중 ENTER 이벤트 발생
search_element.send_keys(Keys.ENTER)

# %%
# 하이퍼링크 의 콘텐츠 데이터가 '쇼핑'인 태그를 선택 
len(driver.find_elements(By.LINK_TEXT, '쇼핑'))
# Out:
# 0

# %%
shopping_button = driver.find_element(By.LINK_TEXT, '쇼핑')

# %%
# 쇼핑 버튼을 클릭한다. 
shopping_button.click()

# %%
# 웹 브라우져(driver)에 있는 HTML 문서를 python으로 가져온다. 
html_data = driver.page_source

# %%
soup = bs(html_data, 'html.parser')

# %%
soup.title
# Out:
# <title>아이폰 : 네이버 검색</title>

# %%
# driver에 탭이 2개가 생기는 경우 
# 일반적으로  driver.page_source를 가져오면 1번 탭의 정보를 제공
# 탭의 정보(주소)를 가져온다 

driver.window_handles
# Out:
# ['9794B536D968C20AC646F16931AB4B2E', '7287DC359937F0E51FCA675BB6C19D85']

# %%
# driver에서 탭을 이동 : 창을 변경 swich_to.whindow(탭의 정보)
driver.switch_to.window(
    driver.window_handles[1]
)

# %%
html_data = driver.page_source
soup = bs(html_data, 'html.parser')

# %%
soup.title
# Out:
# <title data-next-head="">아이폰 : 네이버 가격비교</title>

# %%
# 상품의 정보가 모두 들어는 영역인 div태그 중 id가 content 태그를 추출
items_div = soup.find(
    'div',
    attrs = {
        'id' : 'content'
    }
)

# %%
items_div
# Out:
# <div class="style_content_wrap__Qi3cI" id="content"><div class="style_content__AlF53"><div class="seller_filter_area"><h3 class="blind">판매처</h3><ul class="subFilter_seller_filter__qfsMY"><li class="active _nlog_click _nlog_impression_element" data-shp-area="flt_cor.tab" data-shp-area-id="tab" data-shp-area-type="slot" data-shp-contents-dtl='[{"key":"filter_value_id","value":"total"}]' data-shp-contents-grp="filter" data-shp-contents-id="전체" data-shp-contents-rank="1" data-shp-contents-type="PC 탭" data-shp-inventory="flt_cor" data-shp-nsc="svc.shopping.v3" data-shp-page-key="100360185"><a class="subFilter_filter__KS6xJ" href="#" role="button">전체<span class="subFilter_num__effPz">5,057,427</span><span class="blind">선택됨</span></a></li><li class="_nlog_click _nlog_impression_element" data-shp-area="flt_cor.tab" data-shp-area-id="tab" data-shp-area-type="slot" data-shp-contents-dtl='[{"key":"filter_value_id","value":"model"}]' data-shp-contents-grp="filter" data-shp-contents-id="가격비교" data-shp-contents-rank="2" data-shp-contents-type="PC 탭" data-shp-inventory="flt_cor" data-shp-nsc="svc.shopping.v3" data-shp-page-key="100360185"><a class="subFilter_filter__KS6xJ" href="#" role="button">가격비교</a></li><li class="_nlog_click _nlog_impression_element" data-shp-area="flt_cor.tab" data-shp-area-id="tab" data-shp-area-type="slot" data-shp-contents-dtl='[{"key":"filter_value_id","value":"checkout"}]' data-shp-contents-grp="filter" data-shp-contents-id="네이버페이" data-shp-contents-rank="3" data-shp-contents-type="PC 탭" data-shp-inventory="flt_cor" data-shp-nsc="svc.shopping.v3" data-shp-page-key="100360185"><a class="subFilter_filter__KS6xJ" href="#" role="button">네이버페이</a></li><li class="_nlog_click _nlog_impression_element" data-shp-area="flt_cor.tab" data-shp-area-id="tab" data-shp-area-type="slot" data-shp-contents-dtl='[{"key":"filter_value_id","value":"department"}]' data-shp-contents-grp="filter" data-shp-contents-id="백화점/홈쇼핑" data-shp-contents-rank="4" data-shp-contents-type="PC 탭" data-shp-inventory="flt_cor" data-shp-nsc="svc.shopping.v3" data-shp-page-key="100360185"><a class="subFilter_filter__KS6xJ" href="#" role="button">백화점/홈쇼핑</a></li><li class="_nlog_click _nlog_impression_element" data-shp-area="flt_cor.tab" data-shp-area-id="tab" data-shp-area-type="slot" data-shp-contents-dtl='[{"key":"filter_value_id","value":"window"}]' data-shp-contents-grp="filter" data-shp-contents-id="쇼핑윈도" data-shp-contents-rank="5" data-shp-contents-type="PC 탭" data-shp-inventory="flt_cor" data-shp-nsc="svc.shopping.v3" data-shp-page-key="100360185"><a class="subFilter_filter__KS6xJ" href="#" role="button">쇼핑윈도</a></li><li class="_nlog_click _nlog_impression_element" data-shp-area="flt_cor.tab" data-shp-area-id="tab" data-shp-area-type="slot" data-shp-contents-dtl='[{"key":"filter_value_id","value":"overseas"}]' data-shp-contents-grp="filter" data-shp-contents-id="해외직구" data-shp-contents-rank="6" data-shp-contents-type="PC 탭" data-shp-inventory="flt_cor" data-shp-nsc="svc.shopping.v3" data-shp-page-key="100360185"><a class="subFilter_filter__KS6xJ" href="#" role="button">해외직구</a></li></ul><div class="subFilter_sort_area__h0sxH"><div class="subFilter_sort_box__js3FA"><span class="blind">정렬</span><a class="subFilter_sort__4Q_hv subFilter_is_active__k0gek _nlog_click _nlog_impression_element" data-shp-area="flt_cor.sort" data-shp-area-id="sort" data-shp-area-type="slot" data-shp-contents-grp="filter" data-shp-contents-id="네이버 랭킹순" data-shp-contents-type="정렬옵션" data-shp-inventory="flt_cor" data-shp-nsc="svc.shopping.v3" data-shp-page-key="100360185" href="#" role="button">네이버 랭킹순<span class="blind">선택</span></a><div class="subFilter_layer_ranking__QSyoY"><div class="layer_content"><strong class="subFilter_title__nZDDn">네이버 가격비교 랭킹순</strong><p class="subFilter_text__2Tq4R">적합도 지수, 상품의 인기도/신뢰도 지수 등을 점수화하여 정렬<br/>단, 광고상품은 별도기준에 따라 상단정렬</p><ul class="subFilter_desc__e5zj6"><li><em>적합도 지수</em> : 검색어에 대한 상품 정보 연관도/카테고리 선호도</li><li><em>인기도 지수</em> : 네이버 가격비교를 통 ...

# %%
import re

# %%
len(
    items_div.find_all(
        'div', 
        attrs = {
            'class' : re.compile('adProduct_item')
        }
    )
)
# Out:
# 2

# %%
len(
    items_div.select(
        "div[class^='product_item']"
    )
)
# Out:
# 3

# %%
# product_item들의 상품의 이름과 가격을 추출
# 상품명 -> product_title__xxxxx
# 가격 -> price
# 배송비 -> price_delivery_fee__xxxxx
item_list = items_div.find_all(
    'div', 
    attrs = {
        'class' : re.compile('product_item')
    }
)

# %%
item_list[0].find(
    'span', 
    attrs = {
        'class' : 'price'
    }
).get_text()
# Out:
# '440,000원'

# %%
# 반복문을 이용하여 item_list의 상품명, 가격, 배송비 하나의 2차원 데이터로 생성
values = []

for item in item_list:    
    # 상품명을 추출 
    item_name = item.find(
        'div', 
        attrs = {
            'class' : re.compile('product_title')
        }
    ).get_text()

    # 가격을 추출
    item_price = item.find(
        'span', 
        attrs = {
            'class' : 'price'
        }
    ).get_text()

    # 배송비 추출 
    item_fee = item.find(
        'div', 
        attrs = {
            'class' : re.compile('price_delivery_fee')
        }
    ).get_text()

    # 상품의 링크 주소를 추출 (상품명 추출해서 이 안에서 a태그 찾고 href 속성 값 추출)
    name_tag = item.find(
        'div', 
        attrs = {
            'class' : re.compile('product_title')
        }
    )
    item_url = name_tag.find('a')['href']

    # 상품명과 가격 배송비를 딕셔너리형태로 생성하여 values에 추가 
    values.append(
        {
            '상풍명' : item_name, 
# 2  애플 아이폰13미니 공기계 휴대폰 IPHONE13 MINI 256GB,알뜰폰    354,000원  배송비무료
#
#                                                  url
# 0  https://cr.shopping.naver.com/adcr?x=C8PR8vlEh...
# 1  https://cr.shopping.naver.com/adcr?x=T6IyGWlc0...
# 2  https://cr.shopping.naver.com/adcr?x=jnFhag%2F...

# %% [markdown]
# 1. driver에서 스크롤을 내려준다.
# 2. driver에서 html 문서를 돌려받는다.
# 3. bs()를 이용하여 데이터 파싱
# 4. 상품명, 가격, 배송비, 주소 를 추출하여 데이터프레임으로 완성

# %%
# 스크롤 맨 밑으로 내린다. 
driver.execute_script(
    "window.scrollTo(0, document.body.scrollHeight)"
)

# %%
# driver에서 스크롤 일정 간격으로 내려준다. 
driver.execute_script(
    "window.scrollBy(0, 1000)"
)

# %%
# driver에서 html 문서를 불러온다. 
html_data = driver.page_source
# bs() 타입 변경
soup = bs(html_data, 'html.parser')

# %%
# 상품명, 가격, 배송비, 주소를 추출
items_div = soup.find(
    'div', 
    attrs = {
        'id' : 'content'
    }
)
item_list = items_div.find_all(
    'div', 
    attrs = {
        'class' : re.compile('product_item')
    }
)
len(item_list)
# Out:
# 40

# %%
values = []

for item in item_list:    
    # 상품명을 추출 
    item_name = item.find('div', 
        attrs = {'class' : re.compile('product_title')}
    ).get_text()

    # 가격을 추출
    item_price = item.find('span', 
        attrs = {'class' : 'price'}
    ).get_text()

    # 배송비 추출 
    item_fee = item.find('div', 
        attrs = {'class' : re.compile('price_delivery_fee')}
    ).get_text()

    # 상품의 링크 주소를 추출 (상품명 추출해서 이 안에서 a태그 찾고 href 속성 값 추출)
    name_tag = item.find('div', 
            attrs = {'class' : re.compile('product_title')}
    )
    item_url = name_tag.find('a')['href']

    # 상품명과 가격 배송비를 딕셔너리형태로 생성하여 values에 추가 
    values.append(
        {
            '상풍명' : item_name, 
            '가격' : item_price, 
            '배송비' : item_fee, 
            'url' : item_url
        }
    )

# %%
# 데이터프레임 
df = pd.DataFrame(values)
df
# Out:
#                                                  상풍명            가격  \
# 0                     애플 Apple 아이폰 16e 128GB 미개봉 새제품      440,000원
# 1                                아이폰 17e 256GB [자급제]    최저990,000원
# 2         애플 아이폰13미니 공기계 휴대폰 IPHONE13 MINI 256GB,알뜰폰      354,000원
# 3                                 아이폰 17 512GB [자급제]  최저1,526,400원
# 4                                Apple 정품 아이폰 16 자급제    1,150,000원
# 5                              아이폰 17 프로 256GB [자급제]  최저1,790,000원
# 6             SK 기기변경 애플 아이폰17프로 512G / iphone17 Pro    1,440,000원
# 7                                 아이폰 17 256GB [자급제]  최저1,237,980원
# 8           Apple 아이폰 17 프로 자급제 256GB - 실버 MG8G4KH/A    1,790,000원
# 9                Apple 아이폰17프로맥스 512GB Apple 미개봉 새상품    1,160,000원
# 10                     해외아이폰5C 풀박스 공기계 무음 카메라 8GB 5C       79,000원
# 11                        아이폰 17 256GB Apple 미개봉 새상품      490,000원
# 12                Apple 아이폰 16프로 512GB Apple 미개봉 새상품      890,000원
# 10        배송비무료  https://cr.shopping.naver.com/adcr?x=gTxlbthPm...
# 11        배송비무료  https://cr.shopping.naver.com/adcr?x=N5JKTiduy...
# 12        배송비무료  https://cr.shopping.naver.com/adcr?x=LxPHPhAse...
# 13        배송비무료  https://cr.shopping.naver.com/adcr?x=ozmh4rp7g...
# 14        배송비무료  https://cr.shopping.naver.com/adcr?x=6jviZ%2F%...
# 15        배송비무료  https://cr.shopping.naver.com/adcr?x=DF3kWWns%...
# 16        배송비무료  https://cr.shopping.naver.com/adcr?x=OWZiqmlnU...
# 17        배송비무료  https://cr.shopping.naver.com/adcr?x=DjAKDQS6U...
# 18        배송비무료  https://cr.shopping.naver.com/adcr?x=c1QjyTeiF...
# 19        배송비무료  https://cr.shopping.naver.com/adcr?x=A7Iu2Ztz%...
# 20    배송비3,000원  https://cr.shopping.naver.com/adcr?x=e0jmpyRwA...
# 21        배송비무료  https://cr.shopping.naver.com/adcr?x=jmMr7Ir9Z...
# 22        배송비무료  https://cr.shopping.naver.com/adcr?x=mqLgRc4vQ...
# 23        배송비무료  https://cr.shopping.naver.com/adcr?x=20jncd8FS...
# 24        배송비무료  https://cr.shopping.naver.com/adcr?x=lZzLYNzfO...
# 25        배송비무료  https://cr.shopping.naver.com/adcr?x=v7kJTqqei...
# 26        배송비무료  https://cr.shopping.naver.com/adcr?x=fjtTRejr%...
# 27  배송비100,000원  https://cr.shopping.naver.com/adcr?x=PlsiTydu7...
# 28        배송비무료  https://cr.shopping.naver.com/adcr?x=YXTzKdTc3...
# 29        배송비무료  https://cr.shopping.naver.com/adcr?x=nS1Mcc4V%...
# 30        배송비무료  https://cr.shopping.naver.com/adcr?x=xx%2F02OT...
# 31   배송비16,500원  https://cr.shopping.naver.com/adcr?x=R1Hw5FTqq...
# 32        배송비무료  https://cr.shopping.naver.com/adcr?x=hHszWjJ8u...
# 33        배송비무료  https://cr.shopping.naver.com/adcr?x=diBP2CUpS...
# 34    배송비9,000원  https://cr.shopping.naver.com/adcr?x=F%2FRNuFM...
# 35        배송비무료  https://cr.shopping.naver.com/adcr?x=qlhXYGJEI...
# 36        배송비무료  https://cr.shopping.naver.com/adcr?x=smdwNBqNd...
# 37        배송비무료  https://cr.shopping.naver.com/adcr?x=ulyhR4EJM...
# 38        배송비무료  https://cr.shopping.naver.com/adcr?x=c04nFLvUK...
# 39        배송비무료  https://cr.shopping.naver.com/adcr?x=sfmpzCJHP...

# %%
# csv 파일 저장 
# df.to_csv('아이폰.csv', index=False)

# %%
# 웹 브라우져를 종료
driver.quit()

# %% [markdown]
# - 수집한 데이터를 mysql db server에 저장
#     - db.py module를 이용하여 데이터를 저장
#         - table 생성
#         - insert문을 이용하여 데이터를 하나씩 대입
#         - commit() 함수를 이용해서 동기화
#         - DB server와의 연결을 종료
#
#     - pandas에 to_sql() 함수를 이용해서 데이터 저장
#         - DB server의 연결 주소를 생성 (sqlalchemy 라이브러리)
#         - 데이터프레임의 데이터들은 DB server로 대입

# %%
# db.py 로드 
from db import MyDB

# %%
# 클래스 생성 -> DB 정보를 가진 클래스 
db = MyDB()

# %%
# 데이터가 저장될 table 생성 
# 상품명(varchar(64)), 가격(varchar(32)), 배송비(varchar(32)), url(text)
table_query = """
    CREATE TABLE IF NOT EXISTS `naver_shopping`(
        `No` int PRIMARY KEY AUTO_INCREMENT, 
        `name` VARCHAR(64), 
        `price` VARCHAR(32), 
        `delivery_fee` VARCHAR(32), 
        `url` TEXT
    )
"""

# %%
db.sql_query(
    table_query
)
# Out:
# 'Query OK!'

# %%
df.to_dict('tight')['data'][0]
# Out:
# ['애플 Apple 아이폰 16e 128GB 미개봉 새제품',
#  '440,000원',
#  '배송비무료',
#  'https://cr.shopping.naver.com/adcr?x=C8PR8vlEhHyBiHQdkQNuS%2F%2F%2F%2Fw%3D%3DsEHSEMkxf9CbjK1bbNzhtAM7Br9qGyiHEnrtOB5CZmWQAjU5j3gjlMYsRq8%2BGHFpSSUwYUxYLI5EUUhBTd1QzQzXJD0NsZoE8wg%2BLc2SvDZhHRaISaXjSXtxpkOUV9xcV0b2KJk%2FFg%2BncWB9mF0Gsj2rzo%2FNGFMDzGl%2FMobJ9S8Kj%2FUP%2FAlaMMmuHjPP2KlnchNAWEw0JCsb7LJXBJqKWV9015zgK%2BP5r4ZCysDfiDpW8UjUJYGI%2F9VG8ySwUuOa8QIiRvs9TizWMAADYMU6stDForf4nGUgPwiv53t%2BtlmqAbCY81f975eS5nfR25FBiP83WAv8GAIoQ0MwLPWeb%2FXmSZC2VXfePRV9vZ0UtNyu6RwW64IiqUVCZq0XCYWDGDG4evy%2BM13j64UYOnhTyGUWrQYdwQNgfl5kLUrYkI%2FlvthafyGnI%2BXaLZKUkd9xC%2BQaZNgYJHHKeII8hfQtwaVZe2vCZzrj2VVTjVubWlVDN81WjUpxJVJrN5mDsz4BpxajfCLLAG7AAnOO3EeUKmd9nzMbQIMFh4vy8tzhMHsVda5t7S2YYsJBU1Z1eohHKR2SdzAJDDZAX36C0mf%2BYtdmh3qu3jWpf24Cn5bRk46xB%2BN8yuTUNKdC7BdTtUm5wWfAs3MBjlgxjnwLbwIxH2rPdJcDu90HdysRMHeadvRfOBtPFAtsb0DFBAaEuWZULQ5uWxUwnohxHntA1OSX6yEHQIiXcF4qwUXZ2sX76wW8%3D&nvMid=89877627274&catId=50001519']

# %%
list(df.values[0])
# Out:
# ['애플 Apple 아이폰 16e 128GB 미개봉 새제품',
#  '440,000원',
#  '배송비무료',
#  'https://cr.shopping.naver.com/adcr?x=C8PR8vlEhHyBiHQdkQNuS%2F%2F%2F%2Fw%3D%3DsEHSEMkxf9CbjK1bbNzhtAM7Br9qGyiHEnrtOB5CZmWQAjU5j3gjlMYsRq8%2BGHFpSSUwYUxYLI5EUUhBTd1QzQzXJD0NsZoE8wg%2BLc2SvDZhHRaISaXjSXtxpkOUV9xcV0b2KJk%2FFg%2BncWB9mF0Gsj2rzo%2FNGFMDzGl%2FMobJ9S8Kj%2FUP%2FAlaMMmuHjPP2KlnchNAWEw0JCsb7LJXBJqKWV9015zgK%2BP5r4ZCysDfiDpW8UjUJYGI%2F9VG8ySwUuOa8QIiRvs9TizWMAADYMU6stDForf4nGUgPwiv53t%2BtlmqAbCY81f975eS5nfR25FBiP83WAv8GAIoQ0MwLPWeb%2FXmSZC2VXfePRV9vZ0UtNyu6RwW64IiqUVCZq0XCYWDGDG4evy%2BM13j64UYOnhTyGUWrQYdwQNgfl5kLUrYkI%2FlvthafyGnI%2BXaLZKUkd9xC%2BQaZNgYJHHKeII8hfQtwaVZe2vCZzrj2VVTjVubWlVDN81WjUpxJVJrN5mDsz4BpxajfCLLAG7AAnOO3EeUKmd9nzMbQIMFh4vy8tzhMHsVda5t7S2YYsJBU1Z1eohHKR2SdzAJDDZAX36C0mf%2BYtdmh3qu3jWpf24Cn5bRk46xB%2BN8yuTUNKdC7BdTtUm5wWfAs3MBjlgxjnwLbwIxH2rPdJcDu90HdysRMHeadvRfOBtPFAtsb0DFBAaEuWZULQ5uWxUwnohxHntA1OSX6yEHQIiXcF4qwUXZ2sX76wW8%3D&nvMid=89877627274&catId=50001519']

# %%
# insert 문을 생성 
# 첫번째 컬럼이 No -> auto_increment 기능을 사용 -> 데이터를 넣을 필요가 없음 
insert_query = """
    INSERT INTO `naver_shopping`(
        `name`, `price`, `delivery_fee`, `url`
    )
    VALUES (%s, %s, %s, %s)
"""
# 반복문을 이용해서 데이터프레임의 데이터들을 하나씩 insert 작업 
# len(df)
for i in range(len(df)):
    # i -> 위치 0부터 39까지 
    value = list(df.values[i])
    # print(value)
    # break
    # MyDB 안에 sql_query에 2번째 인자값인 datas 가변인자 허용 -> list 형태를 그대로 입력 x
    # db.sql_query(insert_query, value[0], value[1], value[2], value[3])
    db.sql_query(insert_query, *value)
# Out:
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함
# 접속된 서버가 존재함

# %%
# DB server 동기화
db.commit()

# %%
# sqlalchemy 라이브러리 설치 
# !pip install sqlalchemy

# %%
from sqlalchemy import create_engine

# %%
from urllib.parse import quote_plus

pw = quote_plus('shinjaeho615@')

# create_engine을 이용해서 서버의 정보를 입력 
# sql서버의 주소 : mysql+pymysql://유저명:비밀번호@DB서버의주소:포트번호/데이터베이스명
engine = create_engine(f"mysql+pymysql://root:{pw}@localhost:3306/multicam")

# %%
# DataFrame에 to_sql() 함수를 이용
    # name : 테이블의 이름  (필수)
    # con : 데이터베이스의 주소(engine)  (필수)
    # index : 인덱스 저장 여부 (기본값 : True)
    # if_exists : 
        # replace(교체) -> 기존의 데이터는 제거, 새로운 데이터 대입
        # fail(실패 처리, 기본값) -> 기존의 테이블이 존재하면 에러 발생
        # append(추가) -> 기존의 데이터 밑에 데이터를 추가하는 방식
df.to_sql(name = "naver", con = engine, index=False, if_exists='append')
# Out:
# 40

# %%
from urllib.parse import quote_plus

pw = quote_plus('shinjaeho615@')
engine2 = create_engine(f"mysql+pymysql://test_user:{pw}@localhost:3306/multicam")

# %%
# 테이블 이름은 각자의 이름으로 to_sql() 실행 
df.to_sql(name='shin', con=engine2, index=False)
